# %%
pip install django
# Out:
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.4 MB 254.3 kB/s eta 0:00:31
#    -- ------------------------------------- 0.5/8.4 MB 254.3 kB/s eta 0:00:31
#    -- ------------------------------------- 0.5/8.4 MB 254.3 kB/s eta 0:00:31
#    -- ------------------------------------- 0.5/8.4 MB 254.3 kB/s eta 0:00:31
#    --- ------------------------------------ 0.8/8.4 MB 266.3 kB/s eta 0:00:29
#    --- ------------------------------------ 0.8/8.4 MB 266.3 kB/s eta 0:00:29
# ...

# %%
pip install django psycopg2-binary python-dotenv
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 2.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script dotenv.exe is installed in 'c:\Users\hazim\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
